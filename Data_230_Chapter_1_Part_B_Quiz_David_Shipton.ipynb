# %% [markdown]
# <a href="https://colab.research.google.com/github/NotDaves/hello-world/blob/master/Data_230_Chapter_1_Part_B_Quiz_David_Shipton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chapter 1 part B Quiz Instructions

# %% [markdown]
# Read Chapter 1 of *Essential Math for Data Science* by Thomas Nield. This is available to you through UMGC's Library.
# Look closely at the questions at the end of the chapter and then look at the solutions provided in the appendix.
# When you are ready, work through this notebook to answer these quiz questions. Once you are satisfied with your answers, go to the classroom to submit your answers. You have two attempts, so if you miss a question, come back here to work out another answer.

# %% [markdown]
# # Question 1

# %% [markdown]
# True or False: The slope of the function f(x) = 5x^2 + 3 at x = 4 is 40.

# %% [markdown]
# **Read the section of Chapter 1 on derivatives. To evaluate the slope of function, we take the derivative. A derivative is measuring the rate of change at any point in a function.**

# %% [markdown]
# Following the video on calculating derivatives in the classroom, let's step through the math together. We need to break down each part of the function. First, I will show you how to calculate the derivative of a different function, then you will calculate the derivative of 5*x**2 + 3.

# %% [markdown]
# The step through example is find the slope of the function f(x)= 8*x**2 + 5 when x = 2

# %%
from sympy import *

x = symbols('x')
f = 8*x**2 + 5
plot(f)

# %% [markdown]
# You should now see a parabola.

# %%
#Example find the slope of the function 8*x**2 +5 when x=4
#When we have exponents like x**n (in this case n=2), we find the derivative using this formula: n*x**(n-1)
from math import exp
x=2
first_part= x**2
first_part_derivative=2*x**1
print (first_part_derivative)
#now we have to multiple by the number in front of the x**n, which is 8
first_part_derivative_multiplied= 8*first_part_derivative
print (first_part_derivative_multiplied)
#now we add the second part of the function which is "5". The derivative of any number is 0
completed_derivative= first_part_derivative_multiplied +0
print(completed_derivative)

# %% [markdown]
# Now we can look at the parabola we originally graphed and see that when x=2, the slope of the function is 32 which makes sense. If we go back and rerun this for another value of x, say 3, we get a higher number, 48, which makes sense when we look at the graph, we can see that the value of the output will increase.

# %%
#Example find the slope of the function 8*x**2 +5 when x=4
#When we have exponents like x**n (in this case n=2), we find the derivative using this formula: n*x**(n-1)
from math import exp
x=3
first_part= x**2
first_part_derivative=2*x**1
print (first_part_derivative)
#now we have to multiple by the number in front of the x**n, which is 8
first_part_derivative_multiplied= 8*first_part_derivative
print (first_part_derivative_multiplied)
#now we add the second part of the function which is "5". The derivative of any number is 0
completed_derivative= first_part_derivative_multiplied + 0
print(completed_derivative)

# %% [markdown]
# Using the example from the steps above, you need to find the slope of the function f(x) = 5x^2 + 3 at x = 4.

# %% [markdown]
# Let's start with graphing the function so you can visualize it. Enter the function into the code below next to f=

# %%
from sympy import *

x = symbols('x')
# enter the function below
f =
plot(f)

# %% [markdown]
# Now, we are going to find the derivative using sympy in Python. This is a way to calculate derivatives using Python. In the code below, replace the function next to f= and the value of x you want to know in the last line-replace the #

# %%
from sympy import *

# Declare 'x' to SymPy
x = symbols('x')

# Now just use Python syntax to declare function, enter the function below.
f =

# Calculate the derivative of the function. replace the ? below with the number you are evaluating x at.
dx_f = diff(f)
print(dx_f)
print(dx_f.subs(x,?))

# %% [markdown]
# What answer did you get? Is the statement true or false?

# %% [markdown]
# # Question 2

# %% [markdown]
# What is the slope of the function f(x)= x^(1/3) + x/2-5 at x=8?
#
# A) 2.3
#
# B) 0.583
#
# C) 0.5
#
# D) .033

# %%
from sympy import symbols, diff

# Declare 'x' to SymPy
x = symbols('x')

# Now just use Python syntax to declare function. Enter the function below.
f =

# Calculate the derivative of the function, replace the ? below with the number you are evaluating x at.
dx_f = diff(f)
print(dx_f)
print("%.3f" % dx_f.subs(x,?))

# %% [markdown]
# # Question 3

# %% [markdown]
# True or False: The area under the curve of the function f(x) = 4x^2 + 11 for x between 0 and 3 is 11.

# %%
from sympy import *

x = symbols('x')
# Now just use Python syntax to declare function. Enter the function below.
f =
plot(f)

# %% [markdown]
# To calculate the area under the curve, we use an integral.We can use the integrate feature in SymPy to find this.
# When we use integrate, we pass these arguments:
#
# (integration_variable, lower_limit, upper_limit)

# %%
from sympy import *

# Declare 'x' to SymPy
x = symbols('x')

# Now just use Python syntax to declare function. Enter the function below.
f =

# Calculate the integral of the function with respect to x
# replace the ? below for the area we want to measure under the curve.
area = integrate(f, (x, ?, ?))

print(area)

# %% [markdown]
# # Question 4

# %% [markdown]
# What is the area under the curve of the function f(x) = x^(1/3) + x/2-5 for x between 1/512 and 1/27?

# %% [markdown]
# To calculate the area under the curve, we use an integral.We can use the integrate feature in SymPy to find this.
# When we use integrate, we pass these arguments:
#
# (integration_variable, lower_limit, upper_limit)

# %%
from sympy import *

# Declare 'x' to SymPy
x = symbols('x')

# Now just use Python syntax to declare function. Enter the function below.
f =

# Calculate the integral of the function with respect to x
# replace the ? below for the area we want to measure under the curve.
area = integrate(f, (x, ?, ?))

print("%.3f" % area)
